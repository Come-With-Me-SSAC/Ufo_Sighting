# %%
import pandas as pd
import numpy as np
import os

# %%
forders = os.listdir('C:/Users/JIN SEONG EUN/Desktop/빅데이터 분석가 과정/갖고놀기/00~22')
print(forders)
# Out:
# ['2000_01.csv', '2000_02.csv', '2000_03.csv', '2000_04.csv', '2000_05.csv', '2000_06.csv', '2000_07.csv', '2000_08.csv', '2000_09.csv', '2000_10.csv', '2000_11.csv', '2000_12.csv', '2001_01.csv', '2001_02.csv', '2001_03.csv', '2001_04.csv', '2001_05.csv', '2001_06.csv', '2001_07.csv', '2001_08.csv', '2001_09.csv', '2001_10.csv', '2001_11.csv', '2001_12.csv', '2002_01.csv', '2002_02.csv', '2002_03.csv', '2002_04.csv', '2002_05.csv', '2002_06.csv', '2002_07.csv', '2002_08.csv', '2002_09.csv', '2002_10.csv', '2002_11.csv', '2002_12.csv', '2003_01.csv', '2003_02.csv', '2003_03.csv', '2003_04.csv', '2003_05.csv', '2003_06.csv', '2003_07.csv', '2003_08.csv', '2003_09.csv', '2003_10.csv', '2003_11.csv', '2003_12.csv', '2004_01.csv', '2004_02.csv', '2004_03.csv', '2004_04.csv', '2004_05.csv', '2004_06.csv', '2004_07.csv', '2004_08.csv', '2004_09.csv', '2004_10.csv', '2004_11.csv', '2004_12.csv', '2005_01.csv', '2005_02.csv', '2005_03.csv', '2005_04.csv', '2005_05.csv', '2005_06.csv', '2005_0
# ...

# %%
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[1] == 'csv':
        file = 'C:/Users/JIN SEONG EUN/Desktop/빅데이터 분석가 과정/갖고놀기/00~22/'+forders[i]
        df= pd.read_csv(file,encoding='utf-8') 
        df_all = pd.concat([df_all, df])

# %%
total = df_all

# %%
total.to_csv('C:/Users/JIN SEONG EUN/Desktop/빅데이터 분석가 과정/갖고놀기/total_ufo.csv', sep=',', na_rep='NaN')

# %%
total = pd.read_csv('C:/Users/JIN SEONG EUN/Desktop/빅데이터 분석가 과정/갖고놀기/file_name.csv')
# Out:
# C:\Users\JIN SEONG EUN\AppData\Local\Temp\ipykernel_18280\2327415648.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   total = pd.read_csv('C:/Users/JIN SEONG EUN/Desktop/빅데이터 분석가 과정/갖고놀기/file_name.csv')

# %%
total = total.reset_index(drop= True)

# %%
total
# Out:
#     tablescraper-selected-row  \
# 0               1/31/00 22:21
# 1               1/31/00 21:00
# 2               1/30/00 23:15
# 3               1/30/00 10:30
# 4               1/29/00 13:00
# ..                        ...
# 262              6/1/22 03:36
# 263              6/1/22 03:00
# 264              6/1/22 01:19
# 265              6/1/22 00:01
# 266              6/1/22 00:00
#
#                         tablescraper-selected-row href  \
# 0    https://nuforc.org/webreports/reports/011/S118...
# 1    https://nuforc.org/webreports/reports/058/S585...
# 2    https://nuforc.org/webreports/reports/011/S118...
# 3    https://nuforc.org/webreports/reports/011/S118...
# 4    https://nuforc.org/webreports/reports/011/S118...
# ..                                                 ...
# 262  https://nuforc.org/webreports/reports/168/S168...
# 263  https://nuforc.org/webreports/reports/168/S168...
# 264  https://nuforc.org/webreports/reports/168/S168...
# ...

# %%
total.columns = [ 'date_time','url','city','statecode','country','shape','duration','summary','posted','image']

# %%
total
# Out:
#          date_time                                                url  \
# 0    1/31/00 22:21  https://nuforc.org/webreports/reports/011/S118...
# 1    1/31/00 21:00  https://nuforc.org/webreports/reports/058/S585...
# 2    1/30/00 23:15  https://nuforc.org/webreports/reports/011/S118...
# 3    1/30/00 10:30  https://nuforc.org/webreports/reports/011/S118...
# 4    1/29/00 13:00  https://nuforc.org/webreports/reports/011/S118...
# ..             ...                                                ...
# 262   6/1/22 03:36  https://nuforc.org/webreports/reports/168/S168...
# 263   6/1/22 03:00  https://nuforc.org/webreports/reports/168/S168...
# 264   6/1/22 01:19  https://nuforc.org/webreports/reports/168/S168...
# 265   6/1/22 00:01  https://nuforc.org/webreports/reports/168/S168...
# 266   6/1/22 00:00  https://nuforc.org/webreports/reports/168/S168...
#
#                                 city statecode               country  \
# ...

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119627 entries, 0 to 266
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date_time  119627 non-null  object
#  1   url        119625 non-null  object
#  2   city       119624 non-null  object
#  3   statecode  119611 non-null  object
#  4   country    119563 non-null  object
#  5   shape      119514 non-null  object
#  6   duration   119364 non-null  object
#  7   summary    116315 non-null  object
#  8   posted     104900 non-null  object
#  9   image      475 non-null     object
# dtypes: object(10)
# memory usage: 10.0+ MB

# %%
total['date_time'] = pd.to_datetime(total['date_time'], errors = 'coerce')

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119627 entries, 0 to 266
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date_time  119625 non-null  datetime64[ns]
#  1   url        119625 non-null  object
#  2   city       119624 non-null  object
#  3   statecode  119611 non-null  object
#  4   country    119563 non-null  object
#  5   shape      119514 non-null  object
#  6   duration   119364 non-null  object
#  7   summary    116315 non-null  object
#  8   posted     104900 non-null  object
#  9   image      475 non-null     object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 10.0+ MB

# %%
total['year'] = total['date_time'].dt.year

# %%
total
# Out:
#               date_time                                                url  \
# 0   2000-01-31 22:21:00  https://nuforc.org/webreports/reports/011/S118...
# 1   2000-01-31 21:00:00  https://nuforc.org/webreports/reports/058/S585...
# 2   2000-01-30 23:15:00  https://nuforc.org/webreports/reports/011/S118...
# 3   2000-01-30 10:30:00  https://nuforc.org/webreports/reports/011/S118...
# 4   2000-01-29 13:00:00  https://nuforc.org/webreports/reports/011/S118...
# ..                  ...                                                ...
# 262 2022-06-01 03:36:00  https://nuforc.org/webreports/reports/168/S168...
# 263 2022-06-01 03:00:00  https://nuforc.org/webreports/reports/168/S168...
# 264 2022-06-01 01:19:00  https://nuforc.org/webreports/reports/168/S168...
# 265 2022-06-01 00:01:00  https://nuforc.org/webreports/reports/168/S168...
# 266 2022-06-01 00:00:00  https://nuforc.org/webreports/reports/168/S168...
#
# ...

# %%
total['city'] = total['city'].fillna('null')
total['statecode'] = total['statecode'].fillna('null')
total['shape'] = total['shape'].fillna('null')
total['duration'] = total['duration'].fillna(0)
total['summary'] = total['summary'].fillna('null')

# %%
total.head()
# Out:
#             date_time                                                url  \
# 0 2000-01-31 22:21:00  https://nuforc.org/webreports/reports/011/S118...
# 1 2000-01-31 21:00:00  https://nuforc.org/webreports/reports/058/S585...
# 2 2000-01-30 23:15:00  https://nuforc.org/webreports/reports/011/S118...
# 3 2000-01-30 10:30:00  https://nuforc.org/webreports/reports/011/S118...
# 4 2000-01-29 13:00:00  https://nuforc.org/webreports/reports/011/S118...
#
#                               city statecode country     shape   duration  \
# 0                        Escondido        CA     USA    Circle     8 mins
# 1                   Cape Canaveral        FL     USA     Light   1 minute
# 2  San Francisco (Farallon Island)        CA     USA  Triangle        :15
# 3                   New Wilmington        PA     USA    Circle  2 minutes
# 4                        Beaverton        OR     USA  Cylinder      15min
#
#                                              summary   posted image    year
# ...

# %%
total.isnull().sum()
# Out:
# date_time         2
# url               2
# city              0
# statecode         0
# country          64
# shape             0
# duration          0
# summary           0
# posted        14727
# image        119152
# year              2
# dtype: int64

# %%
total = total.drop(['posted','image'], axis = 1, inplace = False)

# %%
total.isnull().sum()
# Out:
# date_time     2
# url           2
# city          0
# statecode     0
# country      64
# shape         0
# duration      0
# summary       0
# year          2
# dtype: int64

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119627 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date_time  119625 non-null  datetime64[ns]
#  1   url        119625 non-null  object
#  2   city       119627 non-null  object
#  3   statecode  119627 non-null  object
#  4   country    119563 non-null  object
#  5   shape      119627 non-null  object
#  6   duration   119627 non-null  object
#  7   summary    119627 non-null  object
#  8   year       119625 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 9.1+ MB

# %%
total['month'] = total['date_time'].dt.month

# %%
total
# Out:
#               date_time                                                url  \
# 0   2000-01-31 22:21:00  https://nuforc.org/webreports/reports/011/S118...
# 1   2000-01-31 21:00:00  https://nuforc.org/webreports/reports/058/S585...
# 2   2000-01-30 23:15:00  https://nuforc.org/webreports/reports/011/S118...
# 3   2000-01-30 10:30:00  https://nuforc.org/webreports/reports/011/S118...
# 4   2000-01-29 13:00:00  https://nuforc.org/webreports/reports/011/S118...
# ..                  ...                                                ...
# 262 2022-06-01 03:36:00  https://nuforc.org/webreports/reports/168/S168...
# 263 2022-06-01 03:00:00  https://nuforc.org/webreports/reports/168/S168...
# 264 2022-06-01 01:19:00  https://nuforc.org/webreports/reports/168/S168...
# 265 2022-06-01 00:01:00  https://nuforc.org/webreports/reports/168/S168...
# 266 2022-06-01 00:00:00  https://nuforc.org/webreports/reports/168/S168...
#
# ...

# %%
total['day'] = total['date_time'].dt.day
